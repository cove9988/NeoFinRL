# %%
import os
import gym
import numpy as np
import pandas as pd

from stable_baselines3.common.env_checker import check_env
from stable_baselines3 import PPO, TD3
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv,VecNormalize
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.utils import set_random_seed
# from neo_finrl.env_fx_trading.env_fx import tgym
from neo_finrl.env_fx_trading.env_fx_single_pair_window import tgym
env_name ="TradingGym-v0"
env = gym.make(env_name)
check_env(env)
# Out:
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-01-16 00:00:00 -> 2017-01-20 23:55:00 length: 1440
# C:\github\NeoFinRL\.venv\lib\site-packages\stable_baselines3\common\env_checker.py:130: UserWarning: Your observation  has an unconventional shape (neither an image, nor a 1D vector). We recommend you to flatten the observation to have only a 1D vector or use a custom policy to properly process the data.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20324/2389832575.py in <module>
#      13 env_name ="TradingGym-v0"
#      14 env = gym.make(env_name)
# ---> 15 check_env(env)
#
# C:\github\NeoFinRL\.venv\lib\site-packages\stable_baselines3\common\env_checker.py in check_env(env, warn, skip_render_check)
#     276
#     277     # ============ Check the returned values ===============
# --> 278     _check_returned_values(env, observation_space, action_space)
#     279
#     280     # ==== Check the render method and the declared render modes ====
#
# C:\github\NeoFinRL\.venv\lib\site-packages\stable_baselines3\common\env_checker.py in _check_returned_values(env, observation_space, action_space)
#     150                 raise AssertionError(f"Error while checking key={key}: " + str(e))
#     151     else:
# --> 152         _check_obs(obs, observation_space, "reset")
#     153
#     154     # Sample a random action
#
# C:\github\NeoFinRL\.venv\lib\site-packages\stable_baselines3\common\env_checker.py in _check_obs(obs, observation_space, method_name)
#     110         assert isinstance(obs, np.ndarray), f"The observation returned by `{method_name}()` method must be a numpy array"
#     111
# --> 112     assert observation_space.contains(
#     113         obs
#     114     ), f"The observation returned by the `{method_name}()` method does not match the given observation space"
#
# AssertionError: The observation returned by the `reset()` method does not match the given observation space

# %%
env_name ="TradingGym-v0"
def train(df, total_timesteps,model_name, num_cpu = 4, **policy_kwargs):
    # num_cpu Number of processes to use
    # Create the vectorized environment
    # env = SubprocVecEnv([make_env(env_id, i) for i in range(num_cpu)])

    # Stable Baselines provides you with make_vec_env() helper
    # which does exactly the previous steps for you.
    # You can choose between `DummyVecEnv` (usually faster) and `SubprocVecEnv`
    # env = make_vec_env(t, n_envs=num_cpu, seed=0, vec_env_cls=DummyVecEnv)
    env = DummyVecEnv([lambda: tgym(df=df) for _ in range(num_cpu)] )
    # Automatically normalize the input features and reward
    env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)
    if os.path.exists(model_name + '.zip'):
        model = PPO.load(model_name, env=env, )
        print(f'retaining model: {model_name}')
        model.learn(total_timesteps=total_timesteps,**policy_kwargs)
        model.save(model_name)
        env.save("vec_normalize.pkl")
    else:
        print(f'new model: {model_name}')
        model = PPO('MlpPolicy', env=env, **policy_kwargs)
        model.learn(total_timesteps=total_timesteps)
        model.save(model_name)   

model_name = "ppo_fx-2017-4"   
for i in range(0,52): # one year 2017
    
    file = f"./data/split/GBPUSD/weekly/GBPUSD_2017_{i}.csv"
    if os.path.isfile(file):
        print(file)
        df = pd.read_csv(file)
        total_timesteps=200000
        train(df,total_timesteps,model_name)
# Out:
# ./data/split/GBPUSD/weekly/GBPUSD_2017_0.csv
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-01-02 01:00:00 -> 2017-01-06 23:55:00 length: 1428
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-01-02 01:00:00 -> 2017-01-06 23:55:00 length: 1428
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-01-02 01:00:00 -> 2017-01-06 23:55:00 length: 1428
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-01-02 01:00:00 -> 2017-01-06 23:55:00 length: 1428
# new model: ppo_fx-2017-4
# ./data/split/GBPUSD/weekly/GBPUSD_2017_1.csv
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-01-09 00:00:00 -> 2017-01-13 23:55:00 length: 1440
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-01-09 00:00:00 -> 2017-01-13 23:55:00 length: 1440
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-01-09 00:00:00 -> 2017-01-13 23:55:00 length: 1440
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-01-09 00:00:00 -> 2017-01-13 23:55:00 length: 1440
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14288/2143296813.py in <module>
#      32         df = pd.read_csv(file)
#      33         total_timesteps=200000
# ---> 34         train(df,total_timesteps,model_name)
#      35
#
# ~\AppData\Local\Temp/ipykernel_14288/2143296813.py in train(df, total_timesteps, model_name, num_cpu, **policy_kwargs)
#      13     env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)
#      14     if os.path.exists(model_name + '.zip'):
# ---> 15         model = PPO.load(model_name, env=env, **kwargs)
#      16         print(f'retaining model: {model_name}')
#      17         model.learn(total_timesteps=total_timesteps)
#
# NameError: name 'kwargs' is not defined

# %%
import gym
import numpy as np

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.utils import set_random_seed
model = PPO.load("test")

# %%
import gym
from stable_baselines3.common.env_checker import check_env
from neo_finrl.env_fx_trading.env_fx import tgym
env_name ="TradingGym-v1"
env = gym.make(env_name)

# %%
env_name ="TradingGym-v0"
def train(df, total_timesteps,model_name, num_cpu = 4, **policy_kwargs):
    # num_cpu Number of processes to use
    # Create the vectorized environment
    # env = SubprocVecEnv([make_env(env_id, i) for i in range(num_cpu)])

    # Stable Baselines provides you with make_vec_env() helper
    # which does exactly the previous steps for you.
    # You can choose between `DummyVecEnv` (usually faster) and `SubprocVecEnv`
    # env = make_vec_env(t, n_envs=num_cpu, seed=0, vec_env_cls=DummyVecEnv)
    env = DummyVecEnv([lambda: tgym(df=df)] )
    
    # Automatically normalize the input features and reward
    env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)
    if os.path.exists(model_name + '.zip'):
        model = TD3.load(model_name, env=env, **policy_kwargs)
        print(f'retaining model: {model_name}')
        model.learn(total_timesteps=total_timesteps)
        model.save(model_name)
        env.save("vec_normalize.pkl")
    else:
        print(f'new model: {model_name}')
        model = TD3('MlpPolicy', env=env, **policy_kwargs)
        model.learn(total_timesteps=total_timesteps)
        model.save(model_name)   
        

model_name = "td3_fx-2017"   
for i in range(0,52): # one year 2017
    
    file = f"./data/split/GBPUSD/weekly/GBPUSD_2017_{i}.csv"
    if os.path.isfile(file):
        print(file)
        df = pd.read_csv(file)
        total_timesteps=2000
        policy_kwargs ={}
        train(df,total_timesteps,model_name, **policy_kwargs)
# Out:
# ./data/split/GBPUSD/weekly/GBPUSD_2017_0.csv
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-01-02 01:00:00 -> 2017-01-06 23:55:00 length: 1428
# retaining model: td3_fx-2017
# ./data/split/GBPUSD/weekly/GBPUSD_2017_1.csv
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-01-09 00:00:00 -> 2017-01-13 23:55:00 length: 1440
# retaining model: td3_fx-2017
# ./data/split/GBPUSD/weekly/GBPUSD_2017_2.csv
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-01-16 00:00:00 -> 2017-01-20 23:55:00 length: 1440
# retaining model: td3_fx-2017
# ./data/split/GBPUSD/weekly/GBPUSD_2017_3.csv
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-01-23 00:00:00 -> 2017-01-27 23:55:00 length: 1440
# retaining model: td3_fx-2017
# ./data/split/GBPUSD/weekly/GBPUSD_2017_4.csv
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-01-30 00:00:00 -> 2017-02-03 23:55:00 length: 1440
# retaining model: td3_fx-2017
# ./data/split/GBPUSD/weekly/GBPUSD_2017_5.csv
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-02-06 00:00:00 -> 2017-02-10 23:55:00 length: 1440
# retaining model: td3_fx-2017
# ./data/split/GBPUSD/weekly/GBPUSD_2017_6.csv
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-02-13 00:00:00 -> 2017-02-17 23:55:00 length: 1440
# retaining model: td3_fx-2017
# ./data/split/GBPUSD/weekly/GBPUSD_2017_7.csv
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-02-20 00:00:00 -> 2017-02-24 23:55:00 length: 1440
# retaining model: td3_fx-2017
# ./data/split/GBPUSD/weekly/GBPUSD_2017_8.csv
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-02-27 00:00:00 -> 2017-03-03 23:55:00 length: 1440
# retaining model: td3_fx-2017
# ./data/split/GBPUSD/weekly/GBPUSD_2017_9.csv
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-03-06 00:00:00 -> 2017-03-10 23:55:00 length: 1440
# retaining model: td3_fx-2017
# ./data/split/GBPUSD/weekly/GBPUSD_2017_10.csv
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-03-13 00:00:00 -> 2017-03-17 22:55:00 length: 1428
# retaining model: td3_fx-2017
# ./data/split/GBPUSD/weekly/GBPUSD_2017_11.csv
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-03-20 00:00:00 -> 2017-03-24 22:55:00 length: 1428
# retaining model: td3_fx-2017
# ./data/split/GBPUSD/weekly/GBPUSD_2017_12.csv
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-03-27 00:00:00 -> 2017-03-31 23:55:00 length: 1440
# retaining model: td3_fx-2017
# ./data/split/GBPUSD/weekly/GBPUSD_2017_13.csv
# initial done:
# observation_list:['Open', 'High', 'Low', 'Close', 'minute', 'hour', 'day', 'macd', 'boll_ub', 'boll_lb', 'rsi_30', 'dx_30', 'close_30_sma', 'close_60_sma']
#  assets:['GBPUSD']
#  time serial: 2017-04-03 00:00:00 -> 2017-04-07 23:55:00 length: 1440
# retaining model: td3_fx-2017
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14288/2657096287.py in <module>
#      35         total_timesteps=2000
#      36         policy_kwargs ={}
# ---> 37         train(df,total_timesteps,model_name, **policy_kwargs)
#
# ~\AppData\Local\Temp/ipykernel_14288/2657096287.py in train(df, total_timesteps, model_name, num_cpu, **policy_kwargs)
#      16         model = TD3.load(model_name, env=env, **policy_kwargs)
#      17         print(f'retaining model: {model_name}')
# ---> 18         model.learn(total_timesteps=total_timesteps)
#      19         model.save(model_name)
#      20         env.save("vec_normalize.pkl")
#
# C:\github\NeoFinRL\.venv\lib\site-packages\stable_baselines3\td3\td3.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     202     ) -> OffPolicyAlgorithm:
#     203
# --> 204         return super(TD3, self).learn(
#     205             total_timesteps=total_timesteps,
#     206             callback=callback,
#
# C:\github\NeoFinRL\.venv\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     369                 # Special case when the user passes `gradient_steps=0`
#     370                 if gradient_steps > 0:
# --> 371                     self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     372
#     373         callback.on_training_end()
#
# C:\github\NeoFinRL\.venv\lib\site-packages\stable_baselines3\td3\td3.py in train(self, gradient_steps, batch_size)
#     168             self.critic.optimizer.zero_grad()
#     169             critic_loss.backward()
# --> 170             self.critic.optimizer.step()
#     171
#     172             # Delayed policy updates
#
# C:\github\NeoFinRL\.venv\lib\site-packages\torch\optim\optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# C:\github\NeoFinRL\.venv\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# C:\github\NeoFinRL\.venv\lib\site-packages\torch\optim\adam.py in step(self, closure)
#     131                     state_steps.append(state['step'])
#     132
# --> 133             F.adam(params_with_grad,
#     134                    grads,
#     135                    exp_avgs,
#
# C:\github\NeoFinRL\.venv\lib\site-packages\torch\optim\_functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      92             denom = (max_exp_avg_sqs[i].sqrt() / math.sqrt(bias_correction2)).add_(eps)
#      93         else:
# ---> 94             denom = (exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(eps)
#      95
#      96         step_size = lr / bias_correction1
#
# KeyboardInterrupt:
